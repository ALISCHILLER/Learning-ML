# %%
a =3 
b= -31.54
c="x"

bool(a),bool(b),bool(c)
# Out:
# (True, True, True)

# %%
lan = ("python","java","c++","kotlin")
type(lan)
# Out:
# tuple

# %%
print(lan[2])
# Out:
# c++

# %%
list=["java","python","kotlin","c++"]
type(list)
# Out:
# list

# %%
print(list[2])
# Out:
# kotlin

# %%
list[3]="C"

# %%
list
# Out:
# ['java', 'python', 'kotlin', 'C']

# %%
b = list[1:3]
b
# Out:
# ['python', 'kotlin']

# %%
s ={
    "name":"ali",
    "age":2020
}

# %%
type(s)
# Out:
# dict

# %%
a= s["age"]
print(a)
# Out:
# 2020

# %%
print(s.values())
# Out:
# dict_values(['ali', 2020])

# %%
a={1,2,3,4,4,5}
a
# Out:
# {1, 2, 3, 4, 5}

# %%
a={1,2,3,4,4}
a
# Out:
# {1, 2, 3, 4}

# %%
    import math as m
